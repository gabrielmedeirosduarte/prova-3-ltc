# %% [markdown]
# ### <h3> Prova 3 de LTC - Questão 2

# %%
import numpy as np
import sympy as sp
import control as ct
import matplotlib.pyplot as plt

# %% [markdown]
# ##### <h5> Sistema

# %%
s = ct.tf('s')
num_G = [-0.5241, 0.2048]
den_G = [1, 0.7972, 0.1588]
G = ct.tf(num_G, den_G)
n = len(den_G)-1
G
# Out:
# TransferFunction(array([-0.5241,  0.2048]), array([1.    , 0.7972, 0.1588]))

# %% [markdown]
# ##### <h5> Polos e zeros da malha aberta

# %%
print("Polos: ", ct.poles(G))
print("Zeros: ", ct.zeros(G))
# Out:
# Polos:  [-0.40765318+0.j -0.38954682+0.j]
# Zeros:  [0.39076512+0.j]

# %% [markdown]
# ##### <h5> Polos de malha fechada desejados

# %%
p = [-0.6, -0.65, -0.8]

for i in range(len(p)):
    print(p[i])
# Out:
# -0.6
# -0.65
# -0.8

# %% [markdown]
# ##### <h5> Passagem da função de transferência de malha aberta para espaço de estados

# %%
ultima_linha = np.zeros((1, n))
aux = (den_G[::-1])[:-1]

for i in range(len(aux)):
    ultima_linha[0][i] = -aux[i]

A = np.block([[np.zeros((n-1, 1)), np.eye(n-1)],
              [ultima_linha]])

B = np.block([[np.zeros((n-1, 1))],
              [1]])

C = np.zeros((1, n))
for i in range(len(aux)):
    C[0][i] = num_G[::-1][i]

D = np.block([[0]])

print("A: ")
print(A)
print("B: ")
print(B)
print("C: ")
print(C)
print("D: ")
print(D)
# Out:
# A:
# [[ 0.      1.    ]
#  [-0.1588 -0.7972]]
# B:
# [[0.]
#  [1.]]
# C:
# [[ 0.2048 -0.5241]]
# D:
# [[0]]

# %% [markdown]
# ##### <h5> Criação do Espaço de Estado aumentado

# %%
Aa = np.block([[A, np.zeros((n,1))],
               [-C, 0]])

Ba = np.block([[B],
               [0]])

print("Aa:")
print(Aa)
print("Ba:")
print(Ba)
# Out:
# Aa:
# [[ 0.      1.      0.    ]
#  [-0.1588 -0.7972  0.    ]
#  [-0.2048  0.5241  0.    ]]
# Ba:
# [[0.]
#  [1.]
#  [0.]]

# %% [markdown]
# ##### <h5> Cálculo do ganho aumentado

# %%
F = np.array([[-0.6,  0,     0     ],
              [0,    -0.65,  0     ],
              [0,     0,    -0.8   ]])

K_ = np.array([[1, 1, 1]])

T = ct.lyap(Aa, -F, -Ba@K_)

K_a = K_@np.linalg.inv(T)
K = K_a[0][0:n]
Ka = -(K_a[0][-1])
print("K =", K)
print("Ka =", Ka)
# Out:
# K = [2.02963359 1.2528    ]
# Ka = 1.5234374999999485

# %% [markdown]
# ##### <h5> Teste de Observabilidade

# %%
obs = np.linalg.matrix_rank(ct.obsv(A, C))
print("Rank =", obs)
print("Como o rank é igual a 'n', o sistema é observável.")
# Out:
# Rank = 2
# Como o rank é igual a 'n', o sistema é observável.

# %% [markdown]
# ##### <h5> Criação de estrutura de observabilidade

# %%
Fo = 10*np.array([[-0.6,  0     ],
                  [0,    -0.65  ]])

Lo = np.array([[1],
               [1]])

To = ct.lyap(-Fo, A, -Lo@C)

# %% [markdown]
# ##### <h5> Definição da referência de saída e cálculo de Xeq

# %%
# Referência
r = 1

Acl_a = np.block([[A-B@[K], B*Ka],
                  [-C,         0]])
B_a = np.block([[np.zeros((n, 1))],
                [1               ]])

# Xeq
X_eq = -np.linalg.inv(Acl_a)@B_a*r
X_eq
# Out:
# array([[4.8828125 ],
#        [0.        ],
#        [7.01421024]])

# %% [markdown]
# ##### <h5> Simulação em malha fechada

# %%
# Tempo
t0 = 0
tf = 25
Ts = 0.001
time = np.arange(t0, tf, Ts)
amostras = len(time)

# Vetor de referência
ref = np.ones(amostras)*r

# Condição inicial dos estados
x = np.array([[0.0],
              [0.0]])

# Condição inicial do estado do integrador
xa = 0.0

# Condições iniciais dos estados do observador
xo = np.array([[0.001],
               [0.001]])

# Condição inicial dos estados do observador na outra base
z = To@xo

# Criação dos vetores
x_vec = []
xo_vec = []
xa_vec = []
y_vec = []
u_vec = []
v_vec = []

# Simulação
for i in range(len(time)):

    # Sinais de controle
    v = Ka*xa
    u = v - K@xo
    # Saída
    y = (C@x)[0][0]
    # Derivada dos estados do sistema
    x_dot = A@x + B*u
    # Derivada do estado do integrador
    xa_dot = r - y
    # Derivada dos estados do observados na outra base
    z_dot = Fo@z + To@B*u + Lo*y
    # Atualização dos vetores
    x_vec.append(x)
    xo_vec.append(xo)
    xa_vec.append(xa)
    y_vec.append(y)
    u_vec.append(u)
    v_vec.append(v)
    # Atualização dos estados do sistema
    x = x + x_dot*Ts
    # Atualização do estado do integrador
    xa = xa + xa_dot*Ts
    # Atalização dos estados do observador na outra base
    z = z + z_dot*Ts
    # Atalização dos estados do observador
    xo = np.linalg.inv(To)@z

# Separação dos estados do sistema
x1_vec = [v[0][0] for v in x_vec]
x2_vec = [v[1][0] for v in x_vec]

# Separação dos estados observados
xo1_vec = [v[0][0] for v in xo_vec]
xo2_vec = [v[1][0] for v in xo_vec]

plt.figure(figsize=(10,11))

plt.subplot(4, 1, 1)
plt.plot(time, x1_vec, label='$x_1$', color='blue')
plt.plot(time, x2_vec, label='$x_2$', color='orange')
plt.plot(time, xo1_vec, label='$x_{o1}$', color='blue', linestyle='--')
plt.plot(time, xo2_vec, label='$x_{o2}$', color='orange', linestyle='--')
plt.plot(time, xa_vec, label='$x_a$', color='c')
plt.ylabel('Estados')
plt.legend(loc='upper right')
plt.grid()

plt.subplot(4, 1, 2)
plt.plot(time, y_vec, color='m', label='$y$')
plt.plot(time, ref, color='black', label='$ref$', linestyle='--')
plt.ylabel('Saída')
plt.legend(loc='upper right')
plt.grid()

plt.subplot(4, 1, 3)
plt.plot(time, u_vec, color='black', label='$u$')
plt.ylabel('u')
plt.legend(loc='upper right')
plt.grid()

plt.subplot(4, 1, 4)
plt.plot(time, v_vec, color='gray', label='$v$')
plt.xlabel('Tempo')
plt.ylabel('v')
plt.legend(loc='upper right')
plt.grid()

# %% [markdown]
# ##### <h5> Simulação em malha aberta

# %%
# Tempo
t0 = 0
tf = 25
Ts = 0.001
time = np.arange(t0, tf, Ts)
amostras = len(time)

# Vetor de referência
ref = np.ones(amostras)*r

# Resposta ao degrau em malha aberta
t, y = ct.step_response(G, T=time)

# Plot
plt.plot(t, y, color='m', label='$y$')
plt.plot(time, ref, color='black', label='$ref$', linestyle='--')
plt.ylabel('Saída')
plt.xlabel('Tempo')
plt.legend(loc='upper right')
plt.grid()
